# %%
from __future__ import print_function, division, unicode_literals, absolute_import

import sys
import os
import numpy as np

# %matplotlib notebook
from IPython.display import display
#import seaborn as sns   # uncomment this line to activate seaborn settings.

from abipy import abilab

# %%
ncfile = abilab.abiopen('/Users/gmatteo/git_repos/abipy/abipy/data/refs/sio2_screening/sio2_SCR.nc')

# %%
print(ncfile)
# Out:
# ================================= File Info =================================
# Name: sio2_SCR.nc
# Directory: /Users/gmatteo/git_repos/abipy/abipy/data/refs/sio2_screening
# Size: 426.16 kb
# Access Time: Sat Apr 29 13:06:54 2017
# Modification Time: Fri Apr 28 21:32:59 2017
# Change Time: Fri Apr 28 21:32:59 2017
#
# ================================= Structure =================================
# Full Formula (Si3 O6)
# Reduced Formula: SiO2
# abc   :   4.913040   4.913040   5.404630
# angles:  90.000000  90.000000 120.000000
# Sites (9)
#   #  SP         a       b          c
# ---  ----  ------  ------  ---------
#   0  Si     0.465   0       0
#   1  Si     0       0.465   0.666667
#   2  Si    -0.465  -0.465   0.333333
#   3  O      0.415   0.272   0.12
#   4  O     -0.143  -0.415   0.453333
#   5  O     -0.272   0.143   0.786667
#   6  O      0.143  -0.272  -0.12
#   7  O      0.272   0.415   0.546667
#   8  O     -0.415  -0.143   0.213333
#
# ...

# %%
ncfile.params
# Out:
# {'awtr': 1,
#  'gwcalctyp': 2,
#  'gwcomp': 0,
#  'gwencomp': 2.0,
#  'gwgamma': 0,
#  'icutcoul': 6,
#  'ikxc': 0,
#  'inclvkb': 2,
#  'mbpt_sciss': 0.0,
#  'nbands_used': 50,
#  'npwwfn_used': 811,
#  'spmeth': 1,
#  'spsmear': 0.10000000149011612,
#  'test_type': 0,
#  'tordering': 1,
#  'zcut': 0.0036749326}

# %%
fig = ncfile.ebands.plot()
# Out:
# Setting Fermi energy to zero since `fermie_energy` is not initialized in Abinit v8.2
# <img src="data:image/png;base64,..." width="640">

# %%
edos = ncfile.ebands.get_edos()
fig = ncfile.ebands.plot_with_edos(edos)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = ncfile.plot_emacro()
